# %% [markdown]
# # Visualizing Flow Cytometry Data
#
# ## Step 1: Cleaning the data
# Based on information known from the data collected from the flow cytometry machine, the data was cleaned, and initial viauslizations were made

# %%
import pandas
import matplotlib as plt
iRFP_D3 = pandas.read_csv('iRFP+_D3.csv')



#We know we want to ignore B3-B8, so we can remove these rows. We can also remove the mean and SD information (might pull it in later?)
iRFP_D3 = iRFP_D3.iloc[6:]
iRFP_D3 = iRFP_D3.iloc[:-2]

#We also want to graph all Tbets together, all TCFs together, and all negTF together. Essentially, we want one data point per day so that we have three data points total for each sample (Tbet, TCF, negTF)
#This means we average all Tbets, all TCFs, and all negTF

#Before we do that, we can make a plot just for D3.
# %matplotlib inline
plot1 = iRFP_D3.plot(kind='bar', legend=False, title = "Infection Efficiencies in Activated CD8 T Cells: Day 3") #removing the legend that automatically showed up
plot1.axes.get_xaxis().set_ticks([]) #setting ticks to an empty list, add x axis labels later
plot1.set(ylabel="% iRFP+")

#We can do the same for D5 and D7-- repeat the code that's above!
iRFP_D5 = pandas.read_csv('iRFP+_D5.csv')
iRFP_D5 = iRFP_D5.iloc[:-2]
# %matplotlib inline
plot2 = iRFP_D5.plot(kind='bar', legend=False, title = "Infection Efficiencies in Activated CD8 T Cells: Day 5") #removing the legend that automatically showed up
plot2.axes.get_xaxis().set_ticks([]) #setting ticks to an empty list, add x axis labels later
plot2.set(ylabel="% iRFP+")
# Out:
# [Text(0, 0.5, '% iRFP+')]

# %%
iRFP_D7 = pandas.read_csv('iRFP+_D7.csv')
iRFP_D7 = iRFP_D7.iloc[:-5] #need to remove that extra 3*3 that was for Kathleen's experiment (9, 10, 11) from each (??)


# %matplotlib inline
plot3 = iRFP_D7.plot(kind='bar', legend=False, title = "Infection Efficiencies in Activated CD8 T Cells: Day 7") #removing the legend that automatically showed up
plot3.axes.get_xaxis().set_ticks([]) #setting ticks to an empty list, add x axis labels later
plot3.set(ylabel="% iRFP+")
# Out:
# [Text(0, 0.5, '% iRFP+')]

# %% [markdown]
# ## Step 2: Biological Relevance of IL-12
# First, I looked at the difference between different IL-12 concentrations, and their biological effects on TCF and Tbx-21 overexpression over three different time points post infection.

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas

#for day 3, looking at the difference between different IL-12 concentrations

negTF_D3= pandas.read_csv('negTF_iRFP_D3.csv') 
TCF_D3 = pandas.read_csv('TCF_iRFP_D3.csv')
Tbet_D3 = pandas.read_csv('Tbet_iRFP_D3.csv')

plot_negTF = plt.scatter(negTF_D3['IL-12'], negTF_D3['iRFP_percent'])
plot_TCF = plt.scatter(TCF_D3['IL-12'], TCF_D3['iRFP_percent'])
plot_Tbet = plt.scatter(Tbet_D3['IL-12'], Tbet_D3['iRFP_percent'])
plt.xlabel("Concentration of IL-12 (ng)")
plt.ylabel("Percent iRFP+")
plt.title("Day 3 Infection Efficiencies with different concentrations of IL-12")
plt.legend((plot_negTF, plot_TCF, plot_Tbet),('negTF', 'TCF', 'Tbet'))

#need to do line of best fit

# %%
import pandas
from matplotlib import pyplot as plt

negTF_D5 = pandas.read_csv('negTF_iRFP_D5.csv')
TCF_D5 = pandas.read_csv('TCF_iRFP_D5.csv')
Tbet_D5 = pandas.read_csv('Tbet_iRFP_D5.csv')

plot_negTF = plt.scatter(negTF_D5['IL-12'], negTF_D5['iRFP_percent'])
plot_TCF = plt.scatter(TCF_D5['IL-12'], TCF_D5['iRFP_percent'])
plot_Tbet = plt.scatter(Tbet_D5['IL-12'], Tbet_D5['iRFP_percent'])
plt.xlabel("Concentration of IL-12 (ng)")
plt.ylabel("Percent iRFP+")
plt.title("Day 5 Infection Efficiencies with different concentrations of IL-12")
plt.legend((plot_negTF, plot_TCF, plot_Tbet),('negTF', 'TCF', 'Tbet'))

# %%
negTF_D7 = pandas.read_csv('negTF_iRFP_D7.csv')
TCF_D7 = pandas.read_csv('TCF_iRFP_D7.csv')
Tbet_D7 = pandas.read_csv('Tbet_iRFP_D7.csv')

plot_negTF = plt.scatter(negTF_D7['IL-12'], negTF_D7['iRFP_percent'])
plot_TCF = plt.scatter(TCF_D7['IL-12'], TCF_D7['iRFP_percent'])
plot_Tbet = plt.scatter(Tbet_D7['IL-12'], Tbet_D7['iRFP_percent'])
plt.xlabel("Concentration of IL-12 (ng)")
plt.ylabel("Percent iRFP+")
plt.title("Day 7 Infection Efficiencies between Tbet, TCF, and negTF, with different concentrations of IL-12")
plt.legend((plot_negTF, plot_TCF, plot_Tbet),('negTF', 'TCF', 'Tbet'))

# %% [markdown]
# Below is a different way of visualizing the same data-- rather than looking at different time points seperately, each concentration was seperately visualized over three time points in each plot.

# %%
negTF_0IL12 =pandas.read_csv('negTF_0IL-12.csv')
TCF_0IL12 = pandas.read_csv('TCF_0IL-12.csv')
Tbet_0IL12 = pandas.read_csv('Tbet_0IL-12.csv')

plot_negTF_0IL12 = plt.scatter(negTF_0IL12['Day'], negTF_0IL12['iRFP_Percent'])
plot_TCF_0IL12 = plt.scatter(TCF_0IL12['Day'], TCF_0IL12['iRFP_Percent'])
plot_Tbet_0IL12 = plt.scatter(Tbet_0IL12['Day'], Tbet_0IL12['iRFP_Percent'])

plt.legend((plot_negTF_0IL12, plot_TCF_0IL12, plot_Tbet_0IL12),('negTF', 'TCF', 'Tbet'))
plt.xlabel("Days after Infection")
plt.ylabel("Percent iRFP+")
plt.title("Infection Efficiencies between Tbet, TCF, and negTF between Different Days with 0 ng IL-12")
# Out:
# Text(0.5, 1.0, 'Infection Efficiencies between Tbet, TCF, and negTF between Different Days with 0 ng IL-12')

# %%
negTF_5IL12 =pandas.read_csv('negTF_5IL-12.csv')
TCF_5IL12 = pandas.read_csv('TCF_5IL-12.csv')
Tbet_5IL12 = pandas.read_csv('Tbet_5IL-12.csv')

plot_negTF_5IL12 = plt.scatter(negTF_5IL12['Day'], negTF_5IL12['iRFP_Percent'])
plot_TCF_5IL12 = plt.scatter(TCF_5IL12['Day'], TCF_5IL12['iRFP_Percent'])
plot_Tbet_5IL12 = plt.scatter(Tbet_5IL12['Day'], Tbet_5IL12['iRFP_Percent'])

plt.legend((plot_negTF_5IL12, plot_TCF_5IL12, plot_Tbet_5IL12),('negTF', 'TCF', 'Tbet'))
plt.xlabel("Days after Infection")
plt.ylabel("Percent iRFP+")
plt.title("0.05 ng IL-12")
# Out:
# Text(0.5, 1.0, '0.05 ng IL-12')

# %%
negTF_1IL12 =pandas.read_csv('negTF_1IL-12.csv')
TCF_1IL12 = pandas.read_csv('TCF_1IL-12.csv')
Tbet_1IL12 = pandas.read_csv('Tbet_1IL-12.csv')

plot_negTF_1IL12 = plt.scatter(negTF_1IL12['Day'], negTF_1IL12['iRFP_Percent'])
plot_TCF_1IL12 = plt.scatter(TCF_1IL12['Day'], TCF_1IL12['iRFP_Percent'])
plot_Tbet_1IL12 = plt.scatter(Tbet_1IL12['Day'], Tbet_1IL12['iRFP_Percent'])

plt.legend((plot_negTF_1IL12, plot_TCF_1IL12, plot_Tbet_1IL12),('negTF', 'TCF', 'Tbet'))
plt.xlabel("Days after Infection")
plt.ylabel("Percent iRFP+")
plt.title("1 ng IL-12")
# Out:
# Text(0.5, 1.0, '1 ng IL-12')

# %% [markdown]
# ## Step 3: Visualizing Infection Efficiencies at Different Time Points Post-Infection

# %%
import pandas
from matplotlib import pyplot as plt

iRFP_D2 = pandas.read_csv("iRFP_D2.csv")
plot1 = plt.scatter(iRFP_D2['Plate'], iRFP_D2['iRFP_Percent'])

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 10

plt.xlabel("Samples")
plt.ylabel("Percent iRFP+")
plt.title("Infection Efficiencies 24 and 48 Hours After Infection")

iRFP_D3 = pandas.read_csv('Table.csv')
plot2 = plt.scatter(iRFP_D3['Plate'], iRFP_D3['iRFP_Percent'])

plt.legend((plot1, plot2), ('24 hours', '48 hours', 'Tbet'))

# %% [markdown]
# ## Step 4: Visualizing Biological Effects of Ectopic TCF and Tbx-21 Overexpression
#
# A variety of visualizations, each focusing on different time points, are presented below.

# %%
TCF_MFI = pandas.read_csv("TCF_MFI.csv")
plot = plt.bar(TCF_MFI['Plate'], TCF_MFI['TCF_Adjusted'])

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 20

plt.title("TCF Percent Fold Increase as Compared to Negative Conrol on Day 3 Timepoint", fontsize = 20)
plt.xlabel("Levels of IL-12 and Overexpression Construct", fontsize = 15)
plt.ylabel("TCF Percent Fold Increase", fontsize = 15)
# Out:
# Text(0, 0.5, 'TCF Percent Fold Increase')

# %%
import pandas
from matplotlib import pyplot as plt

Tbet_MFI = pandas.read_csv("Tbet_MFI.csv")
plot_tbet = plt.bar(Tbet_MFI['Plate'], Tbet_MFI['Tbet_Adjust'])
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 20

plt.title("Tbet Percent Fold Increase as Compared to Negative Conrol on Day 3 Timepoint", fontsize = 20)
plt.xlabel("Levels of IL-12 and Overexpression Construct", fontsize = 15)
plt.ylabel("Tbet Percent Fold Increase", fontsize = 15)
# Out:
# Text(0, 0.5, 'Tbet Percent Fold Increase')

# %%
import pandas
from matplotlib import pyplot as plt

Tbet_MFI_D5 = pandas.read_csv("Tbet_MFI_D5.csv")
plot_tbet = plt.bar(Tbet_MFI_D5['Plate'], Tbet_MFI_D5['Tbet_Adjusted'])
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 20

plt.title("Tbet Percent Fold Increase as Compared to Negative Conrol on Day 5 Timepoint", fontsize = 20)
plt.xlabel("Levels of IL-12 and Overexpression Construct", fontsize = 15)
plt.ylabel("Tbet Percent Fold Increase", fontsize = 15)
# Out:
# Text(0, 0.5, 'Tbet Percent Fold Increase')

# %%
import pandas
from matplotlib import pyplot as plt

TCF_MFI_D5 = pandas.read_csv("TCF_MFI_D5.csv")
plot_tbet = plt.bar(TCF_MFI_D5['Plate'], TCF_MFI_D5['TCF_Adjusted'])
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 20

plt.title("TCF Percent Fold Increase as Compared to Negative Conrol on Day 5 Timepoint", fontsize = 20)
plt.xlabel("Levels of IL-12 and Overexpression Construct", fontsize = 15)
plt.ylabel("TCF Percent Fold Increase", fontsize = 15)
# Out:
# Text(0, 0.5, 'TCF Percent Fold Increase')

# %% [markdown]
# # Statistical Tests For Data Analysis
#
# ## Statistical Analysis Between Different Overexpression Constructs
#
# We can use the Mann Whitney U test (information from this link:https://scipy-lectures.org/packages/statistics/index.html#hypothesis-testing-comparing-two-groups) to see significance of the differences between overexpression constructs.
#
# H0: distributions for Tbet/TCF between control and different overexpression constructs are the same
#
# Ha: distributions for one of them are different-- check P values against 0.05 (or 0.001)

# %%
#Importing data from flowJo to do statistical analysis tests
import pandas
import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats
from sklearn import preprocessing

#Looking at 0 IL-12
C4 = pandas.read_csv('export_C4_iRFP+ high.csv')
C5 = pandas.read_csv('export_C5_iRFP+ high.csv')
C6 = pandas.read_csv('export_C6_iRFP+ high.csv')
C7 = pandas.read_csv('export_C7_iRFP+ high.csv')

#H0: distributions for Tbet/TCF between control and different overexpression constructs are the same
#Ha: distributions for one of them are different-- check P values against 0.05 (or 0.001)

#The P value measures the strength of evidence against H0. The smaller the P value, the stronger the evidence against H0.


neg_TCF_TCF_0 = stats.mannwhitneyu(C4['TCF1-YFP-A'], C5['TCF1-YFP-A'], alternative='two-sided')
neg_Tbet_TCF_0 = stats.mannwhitneyu(C4['TCF1-YFP-A'], C6['TCF1-YFP-A'], alternative='two-sided')
neg_Id_TCF_0 = stats.mannwhitneyu(C4['TCF1-YFP-A'], C7['TCF1-YFP-A'], alternative='two-sided')

neg_TCF_Tbet_0 = stats.mannwhitneyu(C4['Tbet-AmCyan-A'], C5['Tbet-AmCyan-A'], alternative='two-sided')
neg_Tbet_Tbet_0 = stats.mannwhitneyu(C4['Tbet-AmCyan-A'], C6['Tbet-AmCyan-A'], alternative='two-sided')
neg_Id_Tbet_0 = stats.mannwhitneyu(C4['Tbet-AmCyan-A'], C7['Tbet-AmCyan-A'], alternative='two-sided')

plt.hist(C4['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(C5['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(C6['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(C7['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.show()

#Just as a reminder: C4: neg TF , C5: TCF, C6: Tbet 
# TCF--C4-C5: statistic=340873.5, pvalue=2.489432062558746e-53
# TCF--C4-C6: statistic=555868.0, pvalue=4.4897416766058265e-10 <---
# TCF--C4-C7: statistic=874389.0, pvalue=3.209027661243582e-31
# Tbet--C4-C5: statistic=233728.0, pvalue=0.11033261236711248 <---
# Tbet--C4-C6: statistic=881379.0, pvalue=3.2018956714185286e-46
# Tbet--C4-C7: statistic=557951.5, pvalue=1.3747589050818055e-14

#Between different replicates! Can be significant variability.

# %%
#Looking at 0.05 IL-12

D4 = pandas.read_csv('export_D4_iRFP+ high.csv')
D5 = pandas.read_csv('export_D5_iRFP+ high.csv')
D6 = pandas.read_csv('export_D6_iRFP+ high.csv')
D7 = pandas.read_csv('export_D7_iRFP+ high.csv')

neg_TCF_TCF_5 = stats.mannwhitneyu(D4['TCF1-YFP-A'], D5['TCF1-YFP-A'], alternative='two-sided')
neg_Tbet_TCF_5 = stats.mannwhitneyu(D4['TCF1-YFP-A'], D6['TCF1-YFP-A'], alternative='two-sided')
neg_Id_TCF_5 = stats.mannwhitneyu(D4['TCF1-YFP-A'], D7['TCF1-YFP-A'], alternative='two-sided')

neg_TCF_Tbet_5 = stats.mannwhitneyu(D4['Tbet-AmCyan-A'], D5['Tbet-AmCyan-A'], alternative='two-sided')
neg_Tbet_Tbet_5 = stats.mannwhitneyu(D4['Tbet-AmCyan-A'], D6['Tbet-AmCyan-A'], alternative='two-sided')
neg_Id_Tbet_5 = stats.mannwhitneyu(D4['Tbet-AmCyan-A'], D7['Tbet-AmCyan-A'], alternative='two-sided')

plt.hist(D4['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(D5['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(D6['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(D7['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.show()


# TCF--D4-D5: statistic=898744.5, pvalue=4.848421021143258e-31
# TCF--D4-D6: statistic=1329105.0, pvalue=0.009263844379137026 <---
# TCF--D4-D7: statistic=2368599.0, pvalue=3.0268563884540845e-09
# Tbet--D4-D5: statistic=801318.5, pvalue=1.3120643466136937e-09
# Tbet--D4-D6: statistic=1941427.5, pvalue=2.0143535476571104e-81
# Tbet--D4-D7: statistic=1820976.0, pvalue=9.140820281188196e-17

# %%
#Looking at 1 IL-12

H4 = pandas.read_csv('export_H4_iRFP+ high.csv')
H5 = pandas.read_csv('export_H5_iRFP+ high.csv')
H6 = pandas.read_csv('export_H6_iRFP+ high.csv')
H7 = pandas.read_csv('export_H7_iRFP+ high.csv')

neg_TCF_TCF_1 = stats.mannwhitneyu(H4['TCF1-YFP-A'], H5['TCF1-YFP-A'], alternative='two-sided')
neg_Tbet_TCF_1 = stats.mannwhitneyu(H4['TCF1-YFP-A'], H6['TCF1-YFP-A'], alternative='two-sided')
neg_Id_TCF_1 = stats.mannwhitneyu(H4['TCF1-YFP-A'], H7['TCF1-YFP-A'], alternative='two-sided')

neg_TCF_Tbet_1 = stats.mannwhitneyu(H4['Tbet-AmCyan-A'], H5['Tbet-AmCyan-A'], alternative='two-sided')
neg_Tbet_Tbet_1 = stats.mannwhitneyu(H4['Tbet-AmCyan-A'], H6['Tbet-AmCyan-A'], alternative='two-sided')
neg_Id_Tbet_1 = stats.mannwhitneyu(H4['Tbet-AmCyan-A'], H7['Tbet-AmCyan-A'], alternative='two-sided')

plt.hist(H4['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(H5['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(H6['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.hist(H7['TCF1-YFP-A'], bins=np.logspace(np.log10(1),np.log10(1000000), 100))
plt.xscale('log')

plt.show()

# TCF--H4-H5:: statistic=1450292.5, pvalue=3.803043349416875e-08
# TCF--H4-H6:: statistic=3607898.0, pvalue=0.07969479094230615 <-- ?
# TCF--H4-H7:: statistic=5714577.0, pvalue=0.03255976281537377 <--
# Tbet--H4-H5:: statistic=1485965.5, pvalue=3.14817097411531e-11
# Tbet--H4-H6: statistic=5038572.5, pvalue=1.5645157720342013e-154
# Tbet--H4-H7: statistic=5705779.0, pvalue=0.024826016256574827 <---

# %% [markdown]
# ## Statistical Analysis Between Replicates
# All of the data is loaded into the kernel below, and TCF/Tbet values are compared between them to show significance (or lack of it) between replicates.
#
# H0: distributions of Tbet and TCF between two replicates are the same
#
# Ha: distributions of Tbet and TCF between replicates are different

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats
from sklearn import preprocessing

E5=pandas.read_csv('export_E5_iRFP+ high.csv')
E6=pandas.read_csv('export_E6_iRFP+ high.csv')
E7=pandas.read_csv('export_E7_iRFP+ high.csv')

F4=pandas.read_csv('export_F4_iRFP+ high.csv')
F5=pandas.read_csv('export_F5_iRFP+ high.csv')
F6=pandas.read_csv('export_F6_iRFP+ high.csv')
F7=pandas.read_csv('export_F7_iRFP+ high.csv')

G4=pandas.read_csv('export_G4_iRFP+ high.csv')
G5=pandas.read_csv('export_G5_iRFP+ high.csv')
G6=pandas.read_csv('export_G6_iRFP+ high.csv')
G7=pandas.read_csv('export_G7_iRFP+ high.csv')

#TCF

C4_F4_TCF = stats.mannwhitneyu(C4['TCF1-YFP-A'], F4['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=1196053.0, pvalue=0.005225277720098146)

C5_F5_TCF = stats.mannwhitneyu(C5['TCF1-YFP-A'], F5['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=76443.0, pvalue=0.006721463665720687)

C6_F6_TCF = stats.mannwhitneyu(C6['TCF1-YFP-A'], F6['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=503920.0, pvalue=6.012848167896899e-05)

C7_F7_TCF = stats.mannwhitneyu(C7['TCF1-YFP-A'], F7['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=565388.5, pvalue=4.293861041879992e-06)

D4_G4_TCF = stats.mannwhitneyu(D4['TCF1-YFP-A'], G4['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=2154529.5, pvalue=2.5464446515371034e-14)

D5_G5_TCF = stats.mannwhitneyu(D5['TCF1-YFP-A'], G5['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=184190.5, pvalue=0.008218178867719923)

D6_G6_TCF = stats.mannwhitneyu(D6['TCF1-YFP-A'], G6['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=871691.5, pvalue=4.249031780532571e-12)

D7_G7_TCF = stats.mannwhitneyu(D7['TCF1-YFP-A'], G7['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=2002956.0, pvalue=4.4526542837715857e-29)

E5_H5_TCF = stats.mannwhitneyu(E5['TCF1-YFP-A'], H5['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=403675.0, pvalue=0.05619149857891532)

E6_H6_TCF = stats.mannwhitneyu(E6['TCF1-YFP-A'], H6['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=1209069.0, pvalue=1.2787661176772867e-12)

E7_H7_TCF = stats.mannwhitneyu(E7['TCF1-YFP-A'], H7['TCF1-YFP-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=2963797.0, pvalue=8.629267482916251e-34)

#####Tbet
C4_F4_Tbet = stats.mannwhitneyu(C4['Tbet-AmCyan-A'], F4['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=1104986.5, pvalue=0.31013845138425056) 

C5_F5_Tbet = stats.mannwhitneyu(C5['Tbet-AmCyan-A'], F5['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=68950.5, pvalue=0.8884281762509236) 

C6_F6_Tbet = stats.mannwhitneyu(C6['Tbet-AmCyan-A'], F6['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=447426.0, pvalue=0.499572841180178) 

C7_F7_Tbet = stats.mannwhitneyu(C7['Tbet-AmCyan-A'], F7['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=620885.5, pvalue=0.3100420423968765) 

D4_G4_Tbet = stats.mannwhitneyu(D4['Tbet-AmCyan-A'], G4['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=2393884.0, pvalue=0.039070292915980444) 

D5_G5_Tbet = stats.mannwhitneyu(D5['Tbet-AmCyan-A'], G5['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=180333.0, pvalue=0.0012281533910375288)

D6_G6_Tbet = stats.mannwhitneyu(D6['Tbet-AmCyan-A'], G6['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=924651.0, pvalue=5.7666378338673925e-06)

D7_G7_Tbet = stats.mannwhitneyu(D7['Tbet-AmCyan-A'], G7['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=2186040.5, pvalue=4.137091069498983e-12)

E5_H5_Tbet = stats.mannwhitneyu(E5['Tbet-AmCyan-A'], H5['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=371091.0, pvalue=0.2698553046166121) 

E6_H6_Tbet = stats.mannwhitneyu(E6['Tbet-AmCyan-A'], H6['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=1515532.5, pvalue=0.00013857108526275377)

E7_H7_Tbet = stats.mannwhitneyu(E7['Tbet-AmCyan-A'], H7['Tbet-AmCyan-A'], alternative='two-sided')
#MannwhitneyuResult(statistic=3570792.0, pvalue=0.11382287055393071)
